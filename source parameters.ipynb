# %%
src_array = [
    {"src":"bookings"},
    {"src":"flights"},
    {"src":"airports"},
    {"src":"customers"}
]

# %% [markdown]
# #### Create a control flow so it defines logic and condition here it is a loop

# %%
dbutils.jobs.taskValues.set(key = "output_key",value = src_array)

# %% [markdown]
# ### in the job run
#
# dbutils.jobs.taskValues.set(key="output_key", value=src_array) stores your list as an output of the first notebook, so the For Each task can read that list and run the Bronze notebook once for each item.
